# %%
import pandas as pd
music_rank = pd.read_csv(r'C:\Users\AdminA\Desktop\Blossom files\Assign1\billboard.csv')
music_rank
# Out:
#                  artiste                                  track genre  \
# 0        Destiny's Child               Independent Women Part I  Rock
# 1                Santana                           Maria, Maria  Rock
# 2          Savage Garden                     I Knew I Loved You  Rock
# 3                Madonna                                  Music  Rock
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost   R&B
# 313          Smith, Will                            Freakin' It   Rap
# 314        Zombie Nation                          Kernkraft 400  Rock
# 315       Eastsidaz, The                               Got Beef   Rap
# 316               Fragma                         Toca's Miracle   R&B
#
#     date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  x4th.week  \
# ...

# %%
music_rank_melt = pd.melt(music_rank, id_vars=['artiste','track','genre','date.entered','date.peaked'])
music_rank_melt
# Out:
#                    artiste                                  track genre  \
# 0          Destiny's Child               Independent Women Part I  Rock
# 1                  Santana                           Maria, Maria  Rock
# 2            Savage Garden                     I Knew I Loved You  Rock
# 3                  Madonna                                  Music  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ...                    ...                                    ...   ...
# 24087     Ghostface Killah                       Cherchez LaGhost   R&B
# 24088          Smith, Will                            Freakin' It   Rap
# 24089        Zombie Nation                          Kernkraft 400  Rock
# 24090       Eastsidaz, The                               Got Beef   Rap
# 24091               Fragma                         Toca's Miracle   R&B
#
#       date.entered date.peaked    variable  value
# 0       2000-09-23  2000-11-18   x1st.week   78.0
# ...

# %%
music_rank_melt = music_rank_melt.rename(columns={'variable':'week','value':'rank'})
music_rank_melt
# Out:
#                    artiste                                  track genre  \
# 0          Destiny's Child               Independent Women Part I  Rock
# 1                  Santana                           Maria, Maria  Rock
# 2            Savage Garden                     I Knew I Loved You  Rock
# 3                  Madonna                                  Music  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ...                    ...                                    ...   ...
# 24087     Ghostface Killah                       Cherchez LaGhost   R&B
# 24088          Smith, Will                            Freakin' It   Rap
# 24089        Zombie Nation                          Kernkraft 400  Rock
# 24090       Eastsidaz, The                               Got Beef   Rap
# 24091               Fragma                         Toca's Miracle   R&B
#
#       date.entered date.peaked        week  rank
# 0       2000-09-23  2000-11-18   x1st.week  78.0
# ...

# %%
music_rank_melt.dtypes
# Out:
# artiste          object
# track            object
# genre            object
# date.entered     object
# date.peaked      object
# week             object
# rank            float64
# dtype: object

# %%
music_rank_melt['week'] = music_rank_melt['week'].str.extract('(\d+)').astype(int)
music_rank_melt
# Out:
#                    artiste                                  track genre  \
# 0          Destiny's Child               Independent Women Part I  Rock
# 1                  Santana                           Maria, Maria  Rock
# 2            Savage Garden                     I Knew I Loved You  Rock
# 3                  Madonna                                  Music  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ...                    ...                                    ...   ...
# 24087     Ghostface Killah                       Cherchez LaGhost   R&B
# 24088          Smith, Will                            Freakin' It   Rap
# 24089        Zombie Nation                          Kernkraft 400  Rock
# 24090       Eastsidaz, The                               Got Beef   Rap
# 24091               Fragma                         Toca's Miracle   R&B
#
#       date.entered date.peaked  week  rank
# 0       2000-09-23  2000-11-18     1  78.0
# ...

# %%
music_rank_melt.dtypes
# Out:
# artiste          object
# track            object
# genre            object
# date.entered     object
# date.peaked      object
# week              int32
# rank            float64
# dtype: object

# %%
music_rank_melt['date.entered'] = pd.to_datetime(music_rank_melt['date.entered'])
music_rank_melt['date.peaked'] = pd.to_datetime(music_rank_melt['date.peaked'])

# %%
music_rank_melt['entered_to_peak'] = music_rank_melt['date.peaked'] - music_rank_melt['date.entered']
music_rank_melt
# Out:
#                    artiste                                  track genre  \
# 0          Destiny's Child               Independent Women Part I  Rock
# 1                  Santana                           Maria, Maria  Rock
# 2            Savage Garden                     I Knew I Loved You  Rock
# 3                  Madonna                                  Music  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ...                    ...                                    ...   ...
# 24087     Ghostface Killah                       Cherchez LaGhost   R&B
# 24088          Smith, Will                            Freakin' It   Rap
# 24089        Zombie Nation                          Kernkraft 400  Rock
# 24090       Eastsidaz, The                               Got Beef   Rap
# 24091               Fragma                         Toca's Miracle   R&B
#
#       date.entered date.peaked  week  rank entered_to_peak
# ...

# %%
music_rank_melt['entered_to_peak'] = music_rank_melt['entered_to_peak'].dt.days

# %%
music_rank_melt.head()
# Out:
#                artiste                                  track genre  \
# 0      Destiny's Child               Independent Women Part I  Rock
# 1              Santana                           Maria, Maria  Rock
# 2        Savage Garden                     I Knew I Loved You  Rock
# 3              Madonna                                  Music  Rock
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
#
#   date.entered date.peaked  week  rank  entered_to_peak
# 0   2000-09-23  2000-11-18     1  78.0               56
# 1   2000-02-12  2000-04-08     1  15.0               56
# 2   1999-10-23  2000-01-29     1  71.0               98
# 3   2000-08-12  2000-09-16     1  41.0               35
# 4   2000-08-05  2000-10-14     1  57.0               70

# %%
music_rank_melt
# Out:
#                    artiste                                  track genre  \
# 0          Destiny's Child               Independent Women Part I  Rock
# 1                  Santana                           Maria, Maria  Rock
# 2            Savage Garden                     I Knew I Loved You  Rock
# 3                  Madonna                                  Music  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ...                    ...                                    ...   ...
# 24087     Ghostface Killah                       Cherchez LaGhost   R&B
# 24088          Smith, Will                            Freakin' It   Rap
# 24089        Zombie Nation                          Kernkraft 400  Rock
# 24090       Eastsidaz, The                               Got Beef   Rap
# 24091               Fragma                         Toca's Miracle   R&B
#
#       date.entered date.peaked  week  rank  entered_to_peak
# ...

# %%
rock_1 = music_rank_melt.loc[(music_rank_melt['genre'] == 'Rock') 
                             & (music_rank_melt['rank'] == 1.0) 
                             & (music_rank_melt['entered_to_peak'] == 35), 
                             ['artiste', 'track', 'genre', 'rank', 'entered_to_peak']]
rock_1
# Out:
#       artiste  track genre  rank  entered_to_peak
# 1588  Madonna  Music  Rock   1.0               35
# 1905  Madonna  Music  Rock   1.0               35
# 2222  Madonna  Music  Rock   1.0               35
# 2539  Madonna  Music  Rock   1.0               35

# %%
adadmusic_rank_melt[['artiste', 'track', 'genre', 'rank', 'entered_to_peak']][music_rank_melt['genre'] == 'Rock'][music_rank_melt['rank'] == 1.0][music_rank_melt['entered_to_peak'] == 35]
# Out:
# c:\users\admina\desktop\blossom\blossom_env\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       artiste  track genre  rank  entered_to_peak
# 1588  Madonna  Music  Rock   1.0               35
# 1905  Madonna  Music  Rock   1.0               35
# 2222  Madonna  Music  Rock   1.0               35
# 2539  Madonna  Music  Rock   1.0               35

# %%
music_rank_melt.sample(4)
# Out:
#                 artiste                    track    genre date.entered  \
# 9342           Lonestar                    Smile  Country   1999-12-18
# 34               Blaque       Bring It All To Me      Pop   1999-10-23
# 17863  Houston, Whitney  I Learned From The Best     Rock   2000-02-19
# 1316               Next                    Wifey     Rock   2000-05-27
#
#       date.peaked  week  rank  entered_to_peak
# 9342   2000-02-12    30   0.0               56
# 34     2000-01-22     1  73.0               91
# 17863  2000-03-25    57   0.0               35
# 1316   2000-09-09     5  36.0              105

